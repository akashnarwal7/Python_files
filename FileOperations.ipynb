# %% [markdown]
# # syntax

# %% [markdown]
# ### with open("FileName",mode (read or appendor w)) as fileVariable or filePointer
# ###mode :
# ### r -> read
# ### w -> write
# ### a ->append
# ### rb -> for reading Binary Files by default it reads text files.

# %% [markdown]
# # Iterating Files line By line

# %% [markdown]
# ### for line in filePointer:

# %%
with open("sampleFile.txt",'r') as f:
    i=1
    for line in f:
        print("line {} :".format(i),line)
        i+=1
# Out:
# line 1 : I am akash
#
# line 2 : I am learning AI and ML
#
# line 3 : I am a software Engineer

# %% [markdown]
# ### Advantage of using with
# ### it automatically closes the file.
# ### even error occurs.

# %%
with open("sampleFile.txt",'r') as f:
          # f is filePointer
# to raed
          content=f.read()
          print(content)
# to write
          string="overRidden content"
          f.write(string)
# to append
          string="appending contnet"
          f.write(string)
with open("sampleFile.txt",'r+') as f:
          print(" Reading File :", f.read())
          string="writing again"
          f.write(string)
          print("Readig Again ",f.read())
    
# to read as well as write
          print()
# to write as well as read
# Out:
# <_io.TextIOWrapper name='sampleFile.txt' mode='r' encoding='UTF-8'>
# I am akash
# I am learning AI and ML
# I am a software Engineer
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[10], line 8
#       6 # to write
#       7           string="overRidden content"
# ----> 8           f.write(string)
#       9 # to append
#      10           string="appending contnet"
#
# UnsupportedOperation: not writable

# %%
with open("sampleFile.txt",'r+') as f:
          print(" Reading File :", f.read())
          string="writing again"
          f.write(string)
          print("Readig Again ",f.read())
with op
# Out:
#  Reading File : I am akash
# I am learning AI and ML
# I am a software Engineer
# Readig Again

# %%
try{

    with open("noSuchFile.txt",'r') as f:
       print(f.read())
}
catch{
    
}
