# %% [markdown]
# ###      JSON Module
# ### 1. load : reads from a json file and returns json data converted as pyhton object.
# ### 2. dump : writes in json file python object converted into json data .
# ### 3. loads : converts a string to python object and that string conatins json data as a string.
# ### 4. dumps : converts a python object to string .
#
# ### when json data is in form of stirng consider loads

# %% [markdown]
# ## dump

# %%
import json

obj={
    "name":akash,
    "roll no":10,
    123:4
}
with open("data.json",'w') as f:
    json.dump(obj,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import json
#       3 obj={
# ----> 4     "name":akash,
#       5     "roll no":10,
#       6     123:4
#       7 }
#       8 with open("data.json",'w') as f:
#       9     json.dump(obj,f)
#
# NameError: name 'akash' is not defined
